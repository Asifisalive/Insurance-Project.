# %%
#importing the pacakges
import pandas as pd
import numpy as nm

# %%
data=pd.read_csv("Housing.csv")

# %%
data.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %% [markdown]
# Data Cleaning

# %%
#converting categorical variables into numericcal format - one Hot encoding
data['furnishingstatus']=data['furnishingstatus'].apply({'furnished':1,'semi-furnished':0,'unfurnished':2}.get)

# %%
data.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea  furnishingstatus
# 0              no             yes        2      yes                 1
# 1              no             yes        3       no                 1
# 2              no              no        2      yes                 0
# 3              no             yes        3      yes                 1
# 4              no             yes        2       no                 1

# %%
data['guestroom']=data['guestroom'].apply({'yes':1,'no':0}.get)
data['mainroad']=data['mainroad'].apply({'yes':1,'no':0}.get)
data['basement']=data['basement'].apply({'yes':1,'no':0}.get)
data['hotwaterheating']=data['hotwaterheating'].apply({'yes':1,'no':0}.get)
data['airconditioning']=data['airconditioning'].apply({'yes':1,'no':0}.get)
data['prefarea']=data['prefarea'].apply({'yes':1,'no':0}.get)

# %%
data.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          0
# 1  12250000  8960         4          4        4         1          0
# 2  12250000  9960         3          2        2         1          0
# 3  12215000  7500         4          2        2         1          0
# 4  11410000  7420         4          1        2         1          1
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0         0                0                1        2         1
# 1         0                0                1        3         0
# 2         1                0                0        2         1
# 3         1                0                1        3         1
# 4         1                0                1        2         0
#
#    furnishingstatus
# 0                 1
# 1                 1
# 2                 0
# 3                 1
# 4                 1

# %% [markdown]
# dividing the data into dependent and independent

# %%
x=data[['area','bedrooms','bathrooms','stories','mainroad','guestroom','basement','hotwaterheating','airconditioning','parking','prefarea','furnishingstatus']] #independent variables
y=data['price'] #dependent variables

# %% [markdown]
# splitting the data into training and testing set

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.7) #70% data used for trainig (learning)

# %% [markdown]
# Creating SMLM using linear Regression Algoritham

# %%
from sklearn.linear_model import LinearRegression
regression=LinearRegression() #we are activating our algorithm

# %%
regression.fit(x_train,y_train) #.fit() used for training
# Out:
# LinearRegression()

# %%
y_pred=regression.predict(x_test)

# %%
print(y_pred)
# Out:
# [4710103.56360675 2615106.67280591 7886138.80260783 2264997.55780424
#  6304029.46140986 4977448.2033784  3598338.2669729  7007687.79177076
#  4484538.73569864 7895642.1835153  4965259.36434697 5427863.37578391
#  4984211.65303695 3360260.73259358 4540052.62990264 4439362.77760426
#  3635514.94770879 4256296.78905237 2149758.80591325 5211421.30093057
#  3398639.74008065 7470880.66028841 5746808.61061756 5098759.12542514
#  2625503.49220881 2551057.16587176 6352003.28374657 3385375.77141793
#  4956847.22428784 4772199.21781425 2638181.43333069 5326173.55805206
#  4800953.00476981 4252308.33541499 3353906.13247672 2781567.45397175
#  2908617.06740827 3407403.10872416 2724041.19518442 2441560.09465536
#  8805812.26426177 4809891.74733569 3739586.31322314 2181783.55938032
#  6902221.05978493 3823080.12248727 7519360.84252022 4097111.45322841
#  3804711.57950814 5509237.56939072 5423769.41964265 7101599.03235661
#  6139856.66166287 3212553.24816691 6970509.59352336 6595654.22413914
# ...

# %%
#accuracy of SMLM
regression.score(x,y)
# Out:
# 0.6749742179214766

# %% [markdown]
# New Prediction

# %%
#Genrating new prediction based on genrated dictionary data
new_data={'area':7000,'bedrooms':5,'bathrooms':3,'stories':2,'mainroad':1,'guestroom':0,'basement':1,'hotwaterheating':0,'airconditioning':1,'parking':3,'prefarea':1,'furnishingstatus':3}
index=[1] #serial Number

# %%
my_data=pd.DataFrame(new_data,index)

# %%
my_data
# Out:
#    area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 1  7000         5          3        2         1          0         1
#
#    hotwaterheating  airconditioning  parking  prefarea  furnishingstatus
# 1                0                1        3         1                 3

# %%
new_prediction=regression.predict(my_data)
print("predict the price of the house",new_prediction)
# Out:
# predict the price of the house [9251172.01784886]
